# %% [markdown]
# <div style="background-color: #000502; color: #16a34a; padding: 10px; border-radius: 5px; font-size: 25px; text-align:center">
#   <a class="anchor" id="toc" style="text-decoration: none;">RoughWork1</a>
# </div>

# %%
# Prettifyer code

# ------------------------------------------------------
from rich import print as rprint # For rprinting
from rich.pretty import pprint # For pretty printing
from rich import inspect # For inspect
from rich.console import Console # For console.print
from rich.markdown import Markdown # For markdown
from rich.panel import Panel # For Panel()
from rich import box # For Panel Boxes
from rich.prompt import Prompt # For Prompting 
from rich.style import Style # For styles colors
from rich.text import Text # For text Styles
console = Console() # Standard code to access console
from rich.traceback import install
install(show_locals=True)
# -------------------------------------------------------
# Out:
# <bound method InteractiveShell.excepthook of <ipykernel.zmqshell.ZMQInteractiveShell object at 0x793b692b2620>>

# %%
# Run some simple math here 
import matplotlib.pyplot as plt
import numpy as np

# Create a figure and a set of subplots
fig, ax = plt.subplots(figsize=(6, 6))

# Create a grid of values
x = np.linspace(-10, 10, 400)
y = np.sin(x)

# Plot the function
ax.plot(x, y)

# Turn on the grid
ax.grid(True)

# Function to display the coordinates
def format_coord(x, y):
    return f'x={x:1.4f}, y={y:1.4f}'

# Set the function to format the coordinates
ax.format_coord = format_coord

# Show the plot
plt.show()

# %%
import matplotlib.pyplot as plt

# Create a figure and a set of subplots
fig, ax = plt.subplots(figsize=(6, 6))

# Set the limits of the x and y axes
ax.set_xlim(-600, 600)
ax.set_ylim(-600, 600)

# Turn on the grid
ax.grid(True)

# Function to display the coordinates
def format_coord(x, y):
    return f'x={x:1.4f}, y={y:1.4f}'

# Set the function to format the coordinates
ax.format_coord = format_coord

# Show the plot
plt.show()

# %%
import plotly.graph_objects as go

# Create a figure
fig = go.Figure()

# Set the limits of the x and y axes
fig.update_xaxes(range=[-600, 600])
fig.update_yaxes(range=[-600, 600])

# Turn on the grid
fig.update_layout(xaxis=dict(showgrid=True, gridwidth=1, gridcolor='LightGray'),
                  yaxis=dict(showgrid=True, gridwidth=1, gridcolor='LightGray'))

# Show the plot
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.27.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
import plotly.graph_objects as go

# Create a figure
fig = go.Figure()

# Set the limits of the x and y axes
fig.update_xaxes(range=[-600, 600])
fig.update_yaxes(range=[-600, 600])

# Turn on the grid and set the color to yellow
fig.update_layout(xaxis=dict(showgrid=True, gridwidth=1, gridcolor='yellow', tickfont=dict(color='yellow')),
                  yaxis=dict(showgrid=True, gridwidth=1, gridcolor='yellow', tickfont=dict(color='yellow')),
                  plot_bgcolor='black',
                  paper_bgcolor='black')

# Show the plot
fig.show()
# Out:
# <div>                            <div id="8ecff19b-01eb-4ef8-9a11-0fd115faa736" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8ecff19b-01eb-4ef8-9a11-0fd115faa736")) {                    Plotly.newPlot(                        "8ecff19b-01eb-4ef8-9a11-0fd115faa736",                        [],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"chorople
# ...

# %%
import plotly.graph_objects as go

# Create a figure
fig = go.Figure()

# Set the limits of the x and y axes
fig.update_xaxes(range=[-600, 600])
fig.update_yaxes(range=[-600, 600])

# Turn on the grid and set the color to a dark blue
fig.update_layout(xaxis=dict(showgrid=True, gridwidth=1, gridcolor='darkblue', tickfont=dict(color='darkblue')),
                  yaxis=dict(showgrid=True, gridwidth=1, gridcolor='darkblue', tickfont=dict(color='darkblue')),
                  plot_bgcolor='black',
                  paper_bgcolor='black',
                  hovermode='closest',
                  hoverlabel=dict(bgcolor='black', font=dict(color='yellow')),
                  hovertemplate='x: %{x}<br>y: %{y}')

# Show the plot
fig.show()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:11                                                                                   │
# │                                                                                                  │
# │    8 fig.update_yaxes(range=[-600, 600])                                                         │
# │    9                                                                                             │
# │   10 # Turn on the grid and set the color to a dark blue                                         │
# │ ❱ 11 fig.update_layout(xaxis=dict(showgrid=True, gridwidth=1, gridcolor='darkblue', tickfont=    │
# │   12 │   │   │   │     yaxis=dict(showgrid=True, gridwidth=1, gridcolor='darkblue', tickfont=    │
# │   13 │   │   │   │     plot_bgcolor='black',                                                     │
# ...

# %%
import plotly.graph_objects as go

# Create a figure
fig = go.Figure()

# Set the limits of the x and y axes
fig.update_xaxes(range=[-600, 600])
fig.update_yaxes(range=[-600, 600])

# Turn on the grid and set the color to a dark blue
fig.update_layout(xaxis=dict(showgrid=True, gridwidth=1, gridcolor='darkblue', tickfont=dict(color='darkblue')),
                  yaxis=dict(showgrid=True, gridwidth=1, gridcolor='darkblue', tickfont=dict(color='darkblue')),
                  plot_bgcolor='black',
                  paper_bgcolor='black',
                  hovermode='closest',
                  hoverlabel=dict(bgcolor='black', font=dict(color='yellow')),
                  hovertemplate='x: %{x}<br>y: %{y}<extra></extra>')

# Show the plot
fig.show()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:11                                                                                   │
# │                                                                                                  │
# │    8 fig.update_yaxes(range=[-600, 600])                                                         │
# │    9                                                                                             │
# │   10 # Turn on the grid and set the color to a dark blue                                         │
# │ ❱ 11 fig.update_layout(xaxis=dict(showgrid=True, gridwidth=1, gridcolor='darkblue', tickfont=    │
# │   12 │   │   │   │     yaxis=dict(showgrid=True, gridwidth=1, gridcolor='darkblue', tickfont=    │
# │   13 │   │   │   │     plot_bgcolor='black',                                                     │
# ...

# %%
import plotly.graph_objects as go

# Create a figure
fig = go.Figure()

# Set the limits of the x and y axes
fig.update_xaxes(range=[-600, 600])
fig.update_yaxes(range=[-600, 600])

# Turn on the grid and set the color to a dark blue
fig.update_layout(xaxis=dict(showgrid=True, gridwidth=1, gridcolor='darkblue', tickfont=dict(color='darkblue')),
                  yaxis=dict(showgrid=True, gridwidth=1, gridcolor='darkblue', tickfont=dict(color='darkblue')),
                  plot_bgcolor='black',
                  paper_bgcolor='black',
                  hovermode='closest',
                  template='plotly_dark',
                  hoverlabel=dict(bgcolor='black', font=dict(color='yellow')),
                  hovertemplate='x: %{x}<br>y: %{y}<extra></extra>')

# Show the plot
fig.show()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ in <module>:11                                                                                   │
# │                                                                                                  │
# │    8 fig.update_yaxes(range=[-600, 600])                                                         │
# │    9                                                                                             │
# │   10 # Turn on the grid and set the color to a dark blue                                         │
# │ ❱ 11 fig.update_layout(xaxis=dict(showgrid=True, gridwidth=1, gridcolor='darkblue', tickfont=    │
# │   12 │   │   │   │     yaxis=dict(showgrid=True, gridwidth=1, gridcolor='darkblue', tickfont=    │
# │   13 │   │   │   │     plot_bgcolor='black',                                                     │
# ...
